# %%
"""Julia set generator with PIL-based image drawing"""
import time
from PIL import Image
import array

# area of complex space to investigate
x1, x2, y1, y2 = -1.8, 1.8, -1.8, 1.8
c_real, c_imag = -0.62772, -.42193


def show_greyscale(output_raw, width, height, max_iterations):
    """Convert list to array, show using PIL"""
    # convert our output to PIL-compatible input
    # scale to [0...255]
    max_iterations = float(max(output_raw))
    print(max_iterations)
    scale_factor = float(max_iterations)
    scaled = [int(o / scale_factor * 255) for o in output_raw]
    output = array.array('B', scaled)  # array of unsigned ints
    # display with PIL
    im = Image.new("L", (width, width))
    # EXPLAIN RAW L 0 -1
    im.frombytes(output.tobytes(), "raw", "L", 0, -1)
    im.save('julia_greyscale.png')


def show_false_greyscale(output_raw, width, height, max_iterations):
    """Convert list to array, show using PIL"""
    # convert our output to PIL-compatible input
    assert width * height == len(output_raw)  # sanity check our 1D array and desired 2D form
    # rescale output_raw to be in the inclusive range [0..255]
    max_value = float(max(output_raw))
    output_raw_limited = [int(float(o) / max_value * 255) for o in output_raw]
    # create a slightly fancy colour map that shows colour changes with
    # increased contrast (thanks to John Montgomery)
    output_rgb = ((o + (256 * o) + (256 ** 2) * o) * 16 for o in output_raw_limited)  # fancier
    output_rgb = array.array('I', output_rgb)  # array of unsigned ints (size is platform specific)
    # display with PIL/pillow
    im = Image.new("RGB", (width, height))
    # EXPLAIN RGBX L 0 -1
    im.frombytes(output_rgb.tobytes(), "raw", "RGBX", 0, -1)
    im.save('julia_falseGreyscale.png')


def calculate_z_serial_purepython(maxiter, zs, cs):
    """Calculate output list using Julia update rule"""
    output = [0] * len(zs)
    for i in range(len(zs)):
        n = 0
        z = zs[i]
        c = cs[i]
        while abs(z) < 2 and n < maxiter:
            z = z * z + c
            n += 1
        output[i] = n
    return output


def calc_pure_python(draw_output, desired_width, max_iterations):
    """Create a list of complex co-ordinates (zs) and complex parameters (cs), build Julia set and display"""
    x_step = (x2 - x1) / desired_width
    y_step = (y1 - y2) / desired_width
    x = []
    y = []
    ycoord = y2
    while ycoord > y1:
        y.append(ycoord)
        ycoord += y_step
    xcoord = x1
    while xcoord < x2:
        x.append(xcoord)
        xcoord += x_step
    # set width and height to the generated pixel counts, rather than the
    # pre-rounding desired width and height
    width = len(x)
    height = len(y)
    # build a list of co-ordinates and the initial condition for each cell.
    # Note that our initial condition is a constant and could easily be removed,
    # we use it to simulate a real-world scenario with several inputs to our function
    zs = []
    cs = []
    for ycoord in y:
        for xcoord in x:
            zs.append(complex(xcoord, ycoord))
            cs.append(complex(c_real, c_imag))

    print("Length of x:", len(x))
    print("Total elements:", len(zs))
    start_time = time.time()
    output = calculate_z_serial_purepython(max_iterations, zs, cs)
    end_time = time.time()
    secs = end_time - start_time
    print(calculate_z_serial_purepython.__name__ + " took", secs, "seconds")

    assert sum(output) == 33219980  # this sum is expected for 1000^2 grid with 300 iterations

    if draw_output:
        show_false_greyscale(output, width, height, max_iterations)
        show_greyscale(output, width, height, max_iterations)


if __name__ == "__main__":
    # Calculate the Julia set using a pure Python solution with
    # reasonable defaults for a laptop
    # set draw_output to True to use PIL to draw an image
    calc_pure_python(draw_output=True, desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 4.890553712844849 seconds
# 300.0

# %%
"""Julia set generator without PIL-based image drawing"""
import time

# area of complex space to investigate
x1, x2, y1, y2 = -1.8, 1.8, -1.8, 1.8
c_real, c_imag = -0.62772, -.42193


def calculate_z_serial_purepython(maxiter, zs, cs):
    """Calculate output list using Julia update rule"""
    output = [0] * len(zs)
    for i in range(len(zs)):
        n = 0
        z = zs[i]
        c = cs[i]
        while abs(z) < 2 and n < maxiter:
            z = z * z + c
            n += 1
        output[i] = n
    return output


def calc_pure_python(desired_width, max_iterations):
    """Create a list of complex co-ordinates (zs) and complex parameters (cs), build Julia set and display"""
    x_step = (x2 - x1) / desired_width
    y_step = (y1 - y2) / desired_width
    x = []
    y = []
    ycoord = y2
    while ycoord > y1:
        y.append(ycoord)
        ycoord += y_step
    xcoord = x1
    while xcoord < x2:
        x.append(xcoord)
        xcoord += x_step
    # build a list of co-ordinates and the initial condition for each cell.
    # Note that our initial condition is a constant and could easily be removed,
    # we use it to simulate a real-world scenario with several inputs to our function
    zs = []
    cs = []
    for ycoord in y:
        for xcoord in x:
            zs.append(complex(xcoord, ycoord))
            cs.append(complex(c_real, c_imag))

    print("Length of x:", len(x))
    print("Total elements:", len(zs))
    start_time = time.time()
    output = calculate_z_serial_purepython(max_iterations, zs, cs)
    end_time = time.time()
    secs = end_time - start_time
    print(calculate_z_serial_purepython.__name__ + " took", secs, "seconds")

    assert sum(output) == 33219980  # this sum is expected for 1000^2 grid with 300 iterations


if __name__ == "__main__":
    # Calculate the Julia set using a pure Python solution with
    # reasonable defaults for a laptop
    # set draw_output to True to use PIL to draw an image
    calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 4.720486164093018 seconds

# %%
# Run 10 loops with 5 repetitions

#terminal
#python3 -m timeit -n 10 -r 5 -s "import part1" "part1.calc_pure_python(desired_width=1000, max_iterations=300)"

#notebook
# %timeit -n 10 -r 5 part1.calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       1 # Run 10 loops with 5 repetitions
#       2
#       3 #terminal
#       4 #python3 -m timeit -n 10 -r 5 -s "import part1" "part1.calc_pure_python(desired_width=1000, max_iterations=300)"
#       5
#       6 #notebook
# ----> 7 get_ipython().run_line_magic('timeit', '-n 10 -r 5 part1.calc_pure_python(desired_width=1000, max_iterations=300)')
#
# File ~/.conda/envs/UPY/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.conda/envs/UPY/lib/python3.8/site-packages/IPython/core/magics/execution.py:1174, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1171         if time_number >= 0.2:
#    1172             break
# -> 1174 all_runs = timer.repeat(repeat, number)
#    1175 best = min(all_runs) / number
#    1176 worst = max(all_runs) / number
#
# File ~/.conda/envs/UPY/lib/python3.8/timeit.py:205, in Timer.repeat(self, repeat, number)
#     203 r = []
#     204 for i in range(repeat):
# --> 205     t = self.timeit(number)
#     206     r.append(t)
#     207 return r
#
# File ~/.conda/envs/UPY/lib/python3.8/site-packages/IPython/core/magics/execution.py:158, in Timer.timeit(self, number)
#     156 gc.disable()
#     157 try:
# --> 158     timing = self.inner(it, self.timer)
#     159 finally:
#     160     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# NameError: name 'part1' is not defined

# %%
#Use the cProfile module to profilethe source code 

# terminal
#python3 -m cProfile -s cumulative part1.py
#python3 -m cProfile -o profile.stats part1.py

# notebook
import pstats

p = pstats.Stats("profile.stats")
p.sort_stats("cumulative")

p.print_stats()

p.print_callers()

p.print_callees()
# Out:
# Thu Mar 21 23:40:55 2024    profile.stats
#
#          36221995 function calls in 5.487 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    5.487    5.487 {built-in method builtins.exec}
#         1    0.016    0.016    5.487    5.487 part1.py:1(<module>)
#         1    0.208    0.208    5.471    5.471 part1.py:23(calc_pure_python)
#         1    3.721    3.721    5.207    5.207 part1.py:9(calculate_z_serial_purepython)
#  34219980    1.487    0.000    1.487    0.000 {built-in method builtins.abs}
#   2002000    0.053    0.000    0.053    0.000 {method 'append' of 'list' objects}
#         1    0.002    0.002    0.002    0.002 {built-in method builtins.sum}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#
#
#    Ordered by: cumulative time
#
# Function                                          was called by...
#                                                       ncalls  tottime  cumtime
# {built-in method builtins.exec}                   <-
# part1.py:1(<module>)                              <-       1    0.016    5.487  {built-in method builtins.exec}
# part1.py:23(calc_pure_python)                     <-       1    0.208    5.471  part1.py:1(<module>)
# part1.py:9(calculate_z_serial_purepython)         <-       1    3.721    5.207  part1.py:23(calc_pure_python)
# {built-in method builtins.abs}                    <- 34219980    1.487    1.487  part1.py:9(calculate_z_serial_purepython)
# {method 'append' of 'list' objects}               <- 2002000    0.053    0.053  part1.py:23(calc_pure_python)
# {built-in method builtins.sum}                    <-       1    0.002    0.002  part1.py:23(calc_pure_python)
# {built-in method builtins.print}                  <-       3    0.000    0.000  part1.py:23(calc_pure_python)
# {method 'disable' of '_lsprof.Profiler' objects}  <-
# {built-in method time.time}                       <-       2    0.000    0.000  part1.py:23(calc_pure_python)
# {built-in method builtins.len}                    <-       2    0.000    0.000  part1.py:9(calculate_z_serial_purepython)
#                                                            2    0.000    0.000  part1.py:23(calc_pure_python)
#
#
#    Ordered by: cumulative time
#
# Function                                          called...
#                                                       ncalls  tottime  cumtime
# {built-in method builtins.exec}                   ->       1    0.016    5.487  part1.py:1(<module>)
# part1.py:1(<module>)                              ->       1    0.208    5.471  part1.py:23(calc_pure_python)
# part1.py:23(calc_pure_python)                     ->       1    3.721    5.207  part1.py:9(calculate_z_serial_purepython)
#                                                            2    0.000    0.000  {built-in method builtins.len}
#                                                            3    0.000    0.000  {built-in method builtins.print}
#                                                            1    0.002    0.002  {built-in method builtins.sum}
#                                                            2    0.000    0.000  {built-in method time.time}
#                                                      2002000    0.053    0.053  {method 'append' of 'list' objects}
# part1.py:9(calculate_z_serial_purepython)         -> 34219980    1.487    1.487  {built-in method builtins.abs}
#                                                            2    0.000    0.000  {built-in method builtins.len}
# {built-in method builtins.abs}                    ->
# {method 'append' of 'list' objects}               ->
# {built-in method builtins.sum}                    ->
# {built-in method builtins.print}                  ->
# {method 'disable' of '_lsprof.Profiler' objects}  ->
# {built-in method time.time}                       ->
# {built-in method builtins.len}                    ->

# %%
#Use snakeviz to get a high-level understanding of thecPrifile statistics file

# terminal
#snakeviz profile.stats

# notebook
# %load_ext snakeviz
# %snakeviz calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# The snakeviz extension is already loaded. To reload it, use:
#   %reload_ext snakeviz
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 7.667720317840576 seconds
#
# *** Profile stats marshalled to file '/tmp/tmpd5ejgrd7'.
# Embedding SnakeViz in this document...
# <function display at 0x72c25ac05700>
# <iframe id='snakeviz-9836f1f0-ea64-11ee-834c-701ab81a3f38' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-9836f1f0-ea64-11ee-834c-701ab81a3f38").setAttribute("src", "http://" + document.location.hostname + ":8081/snakeviz/%2Ftmp%2Ftmpd5ejgrd7")</script>

# %%
# Use the line_profiler and kernprof file to profile line-by-line the function calculate_z_serial_purepython.

# run in terminal the following commands
#kernprof -l -v part1_lineprofiler.py
#kernprof -l -v part1_lineprofiler2.py

# %%
# Use the memory_profiler to diagnose memory usage

# run in terminal the following commands
#python3 -m memory_profiler part1_memoryprofiler.py
